# %% [markdown]
# # Trexquant Interview Project (The Hangman Game)
#
# * Copyright Trexquant Investment LP. All Rights Reserved.
# * Redistribution of this question without written consent from Trexquant is prohibited

# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import string
import json
import requests
import torch
import numpy as np
import time
import re
import collections

from collections import Counter
from train_model import BalancedFeatureExtractor
from hangman_model import HangmanNN

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# Constants
MAX_WORD_LENGTH = 20
NUM_LETTERS = len(string.ascii_lowercase)  # 26

# Calculate feature size components
PATTERN_FEATURES = MAX_WORD_LENGTH  # 20
GUESSED_FEATURES = NUM_LETTERS  # 26
NGRAM_FEATURES = NUM_LETTERS * 3  # 78 (unigram, bigram, and trigram scores)
LETTER_FREQ_FEATURES = NUM_LETTERS  # 26
STRUCTURE_FEATURES = 2  # 2
RATIO_FEATURES = 2  # 2
REMAINING_FEATURES = NUM_LETTERS  # 26 (scores for remaining positions)
REMAINING_META_FEATURES = 3  # 3 (num_remaining, remaining_guesses, context_importance)

# Total feature size
FEATURE_SIZE = (
        PATTERN_FEATURES +  # 20
        GUESSED_FEATURES +  # 26
        NGRAM_FEATURES +  # 78
        LETTER_FREQ_FEATURES +  # 26
        STRUCTURE_FEATURES +  # 2
        RATIO_FEATURES +  # 2
        REMAINING_FEATURES +  # 26
        REMAINING_META_FEATURES  # 3
)  # Total: 183

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        # Original initialization
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []

        # Load dictionary for fallback
        full_dictionary_location = "words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)
        self.full_dictionary_common_letter_sorted = Counter("".join(self.full_dictionary)).most_common()
        self.current_dictionary = []

        # Initialize model and feature extractor
        self.device = torch.device("cpu")  # Use CPU for inference
        self.model = None
        self.feature_extractor = None
        self.load_model("models/hangman_model.pt")

    def load_model(self, model_path):
        """Load the enhanced model"""
        print(f"Loading model with input size {FEATURE_SIZE}")
        try:
            # Initialize model
            self.model = HangmanNN().to(self.device)
            checkpoint = torch.load(model_path, map_location=self.device, weights_only=True)
            self.model.load_state_dict(checkpoint['model_state_dict'])
            self.model.eval()

            # Initialize feature extractor
            self.feature_extractor = BalancedFeatureExtractor(self.full_dictionary)

            print("Model and feature extractor loaded successfully")
            return self.model
        except Exception as e:
            print(f"Error loading model: {e}")
            print("Falling back to frequency-based approach")
            self.model = None
            self.feature_extractor = None
            return None
        
    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com', 'https://sg.trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link

    def _frequency_based_guess(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        clean_word = word[::2].replace("_",".")
        
        # find length of passed word
        len_word = len(clean_word)
        
        # grab current dictionary of possible words from self object, initialize new possible words dictionary to empty
        current_dictionary = self.current_dictionary
        new_dictionary = []
        
        # iterate through all of the words in the old plausible dictionary
        for dict_word in current_dictionary:
            # continue if the word is not of the appropriate length
            if len(dict_word) != len_word:
                continue
                
            # if dictionary word is a possible match then add it to the current dictionary
            if re.match(clean_word,dict_word):
                new_dictionary.append(dict_word)
        
        # overwrite old possible words dictionary with updated version
        self.current_dictionary = new_dictionary
        
        
        # count occurrence of all characters in possible word matches
        full_dict_string = "".join(new_dictionary)
        
        c = collections.Counter(full_dict_string)
        sorted_letter_count = c.most_common()                   
        
        guess_letter = '!'
        
        # return most frequently occurring letter in all possible words that hasn't been guessed yet
        for letter,instance_count in sorted_letter_count:
            if letter not in self.guessed_letters:
                guess_letter = letter
                break
            
        # if no word matches in training dictionary, default back to ordering of full dictionary
        if guess_letter == '!':
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter,instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break            
        
        return guess_letter

    def guess(self, word):
        """Make a guess using enhanced features"""
        if self.model is None or self.feature_extractor is None:
            return self._frequency_based_guess(word)

        try:
            # Extract enhanced features
            features = self.feature_extractor.extract_features_balanced(word, self.guessed_letters, self.device)

            # Get model predictions
            with torch.no_grad():
                predictions = torch.sigmoid(self.model(features.unsqueeze(0)))

            # Convert predictions to probabilities and mask out guessed letters
            probs = predictions[0].cpu().numpy()
            for letter in self.guessed_letters:
                idx = ord(letter.lower()) - ord('a')
                probs[idx] = -1

            # Get the highest probability letter
            best_idx = np.argmax(probs)
            guess_letter = chr(best_idx + ord('a'))

            return guess_letter
        except Exception as e:
            print(f"Error during prediction: {e}")
            return self._frequency_based_guess(word)

    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
                
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="4cb04386c3f23b53cde4597dd08f0f", timeout=2000)
# Out:
# Loading model with input size 102
# Initializing Balanced Feature Extractor...
# Dictionary size after filtering: 227127 words
# Pre-computing word letter positions...
#   0%|          | 0/227127 [00:00<?, ?it/s]
# Building positional n-grams...
# Computing n-grams:   0%|          | 0/227127 [00:00<?, ?it/s]
# Model and feature extractor loaded successfully

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
for _ in range(1000):
    api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    practice_success_rate = (total_practice_successes - 1319) / (total_practice_runs - 3394)
    print('run %d practice games. practice success rate so far = %.3f' % (total_practice_runs-3394, practice_success_rate))
    time.sleep(1)
# Out:
# Successfully start a new game! Game ID: 9ff8f3228c98. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i _ i _ _ _ _ i _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ a i _ i _ _ _ _ i _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ a i _ i _ _ _ o i _ _ '}
# Guessing letter: u
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ a i _ i _ _ _ o i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ a i _ i n _ _ o i n _ '}
# Guessing letter: s
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ a i _ i n _ _ o i n _ '}
# Guessing letter: r
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r a i _ i n _ _ o i n _ '}
# Guessing letter: l
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r a i l i n _ _ o i n _ '}
# Guessing letter: c
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ r a i l i n _ _ o i n _ '}
# Guessing letter: t
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 2, 'word': 't r a i l i n _ _ o i n t '}
# Guessing letter: y
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'ongoing', 'tries_remains': 1, 'word': 't r a i l i n _ _ o i n t '}
# Guessing letter: d
# Sever response: {'game_id': '9ff8f3228c98', 'status': 'failed', 'tries_remains': 0, 'word': 't r a i l i n _ _ o i n t '}
# Failed game: 9ff8f3228c98. Because of: # of tries exceeded!
# run 1 practice games. practice success rate so far = 0.000
# Successfully start a new game! Game ID: 9c9521c519ad. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ e _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ e _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ a _ e _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ a _ e _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ a _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e r _ a _ e _ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e r _ a _ e _ c _ '}
# Guessing letter: n
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e r _ a _ e n c _ '}
# Guessing letter: l
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e r _ a l e n c _ '}
# Guessing letter: t
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 3, 'word': 't e r _ a l e n c _ '}
# Guessing letter: v
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 3, 'word': 't e r v a l e n c _ '}
# Guessing letter: b
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 2, 'word': 't e r v a l e n c _ '}
# Guessing letter: j
# Sever response: {'game_id': '9c9521c519ad', 'status': 'ongoing', 'tries_remains': 1, 'word': 't e r v a l e n c _ '}
# Guessing letter: f
# Sever response: {'game_id': '9c9521c519ad', 'status': 'failed', 'tries_remains': 0, 'word': 't e r v a l e n c _ '}
# Failed game: 9c9521c519ad. Because of: # of tries exceeded!
# run 2 practice games. practice success rate so far = 0.000
# Successfully start a new game! Game ID: eca3e180ee72. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ a _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ i _ _ _ a _ i _ '}
# Guessing letter: o
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ i _ o _ a _ i _ '}
# Guessing letter: n
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i _ i _ o _ a _ i _ '}
# Guessing letter: s
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i _ i _ o _ a s i s '}
# Guessing letter: r
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i r i _ o _ a s i s '}
# Guessing letter: l
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i r i _ o _ a s i s '}
# Guessing letter: u
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'ongoing', 'tries_remains': 2, 'word': 'i r i _ o _ a s i s '}
# Guessing letter: t
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'ongoing', 'tries_remains': 2, 'word': 'i r i _ o t a s i s '}
# Guessing letter: c
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'ongoing', 'tries_remains': 1, 'word': 'i r i _ o t a s i s '}
# Guessing letter: y
# Sever response: {'game_id': 'eca3e180ee72', 'status': 'failed', 'tries_remains': 0, 'word': 'i r i _ o t a s i s '}
# Failed game: eca3e180ee72. Because of: # of tries exceeded!
# run 3 practice games. practice success rate so far = 0.000
# Successfully start a new game! Game ID: 5046778245e7. # of tries remaining: 6. Word: _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '5046778245e7', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ a '}
# Guessing letter: e
# Sever response: {'game_id': '5046778245e7', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a '}
# Guessing letter: i
# Sever response: {'game_id': '5046778245e7', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ a '}
# Guessing letter: o
# Sever response: {'game_id': '5046778245e7', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ o _ a '}
# Guessing letter: n
# Sever response: {'game_id': '5046778245e7', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o _ a '}
# Guessing letter: s
# Sever response: {'game_id': '5046778245e7', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o _ a '}
# Guessing letter: c
# Sever response: {'game_id': '5046778245e7', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o _ a '}
# Guessing letter: r
# Sever response: {'game_id': '5046778245e7', 'status': 'failed', 'tries_remains': 0, 'word': '_ o _ a '}
# Failed game: 5046778245e7. Because of: # of tries exceeded!
# run 4 practice games. practice success rate so far = 0.000
# Successfully start a new game! Game ID: 24dba364dc8d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '24dba364dc8d', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': '24dba364dc8d', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ _ _ a _ e '}
# Guessing letter: i
# Sever response: {'game_id': '24dba364dc8d', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ _ a _ e '}
# Guessing letter: o
# Sever response: {'game_id': '24dba364dc8d', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ o _ a _ e '}
# Guessing letter: n
# Sever response: {'game_id': '24dba364dc8d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ o _ a _ e '}
# Guessing letter: r
# Sever response: {'game_id': '24dba364dc8d', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ o _ a _ e '}
# Guessing letter: l
# Sever response: {'game_id': '24dba364dc8d', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a l l o _ a _ e '}
# Guessing letter: s
# Sever response: {'game_id': '24dba364dc8d', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a l l o _ a _ e '}
# Guessing letter: u
# Sever response: {'game_id': '24dba364dc8d', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a l l o _ a _ e '}
# Guessing letter: c
# Sever response: {'game_id': '24dba364dc8d', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a l l o c a _ e '}
# Guessing letter: t
# Sever response: {'game_id': '24dba364dc8d', 'status': 'success', 'tries_remains': 1, 'word': 'a l l o c a t e '}
# Successfully finished game: 24dba364dc8d
# run 5 practice games. practice success rate so far = 0.200
# Successfully start a new game! Game ID: 3fe480d2e0d3. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ _ e _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ i _ _ _ e _ i _ _ '}
# Guessing letter: g
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ i g _ _ e _ i _ g '}
# Guessing letter: n
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 6, 'word': 'n _ n e n _ i g _ _ e n i n g '}
# Guessing letter: o
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 6, 'word': 'n o n e n _ i g _ _ e n i n g '}
# Guessing letter: s
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n o n e n _ i g _ _ e n i n g '}
# Guessing letter: l
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n o n e n l i g _ _ e n i n g '}
# Guessing letter: t
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n o n e n l i g _ t e n i n g '}
# Guessing letter: r
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 4, 'word': 'n o n e n l i g _ t e n i n g '}
# Guessing letter: u
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n o n e n l i g _ t e n i n g '}
# Guessing letter: c
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n o n e n l i g _ t e n i n g '}
# Guessing letter: a
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'ongoing', 'tries_remains': 1, 'word': 'n o n e n l i g _ t e n i n g '}
# Guessing letter: m
# Sever response: {'game_id': '3fe480d2e0d3', 'status': 'failed', 'tries_remains': 0, 'word': 'n o n e n l i g _ t e n i n g '}
# Failed game: 3fe480d2e0d3. Because of: # of tries exceeded!
# run 6 practice games. practice success rate so far = 0.167
# Successfully start a new game! Game ID: c40a4e345ffd. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ _ _ _ a _ '}
# Guessing letter: o
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ _ o _ a _ '}
# Guessing letter: c
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ c _ _ _ i _ _ o _ a _ '}
# Guessing letter: s
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 5, 'word': 's c _ _ _ i s _ o _ a s '}
# Guessing letter: n
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 4, 'word': 's c _ _ _ i s _ o _ a s '}
# Guessing letter: r
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 3, 'word': 's c _ _ _ i s _ o _ a s '}
# Guessing letter: l
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 2, 'word': 's c _ _ _ i s _ o _ a s '}
# Guessing letter: t
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 2, 'word': 's c _ _ _ i s t o _ a s '}
# Guessing letter: m
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 2, 'word': 's c _ _ _ i s t o m a s '}
# Guessing letter: u
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 1, 'word': 's c _ _ _ i s t o m a s '}
# Guessing letter: y
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'ongoing', 'tries_remains': 1, 'word': 's c y _ _ i s t o m a s '}
# Guessing letter: d
# Sever response: {'game_id': 'c40a4e345ffd', 'status': 'failed', 'tries_remains': 0, 'word': 's c y _ _ i s t o m a s '}
# Failed game: c40a4e345ffd. Because of: # of tries exceeded!
# run 7 practice games. practice success rate so far = 0.143
# Successfully start a new game! Game ID: ace6f510e04b. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ _ _ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ _ _ i _ e '}
# Guessing letter: n
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ _ _ i n e '}
# Guessing letter: l
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ _ i n e '}
# Guessing letter: r
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a r _ _ _ i n e '}
# Guessing letter: c
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a r _ _ _ i n e '}
# Guessing letter: m
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a r _ _ _ i n e '}
# Guessing letter: s
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a r _ _ _ i n e '}
# Guessing letter: o
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a r _ o _ i n e '}
# Guessing letter: v
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a r _ o _ i n e '}
# Guessing letter: p
# Sever response: {'game_id': 'ace6f510e04b', 'status': 'failed', 'tries_remains': 0, 'word': '_ a r _ o _ i n e '}
# Failed game: ace6f510e04b. Because of: # of tries exceeded!
# run 8 practice games. practice success rate so far = 0.125
# Successfully start a new game! Game ID: 373856953a74. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '373856953a74', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '373856953a74', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i _ _ _ _ _ i _ '}
# Guessing letter: a
# Sever response: {'game_id': '373856953a74', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ i _ _ _ _ _ i _ '}
# Guessing letter: o
# Sever response: {'game_id': '373856953a74', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ i _ o _ o _ i _ '}
# Guessing letter: c
# Sever response: {'game_id': '373856953a74', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ c _ i _ o _ o _ i c '}
# Guessing letter: n
# Sever response: {'game_id': '373856953a74', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ c _ i _ o _ o n i c '}
# Guessing letter: s
# Sever response: {'game_id': '373856953a74', 'status': 'ongoing', 'tries_remains': 4, 'word': 's c _ i _ o _ o n i c '}
# Guessing letter: r
# Sever response: {'game_id': '373856953a74', 'status': 'ongoing', 'tries_remains': 3, 'word': 's c _ i _ o _ o n i c '}
# Guessing letter: l
# Sever response: {'game_id': '373856953a74', 'status': 'ongoing', 'tries_remains': 2, 'word': 's c _ i _ o _ o n i c '}
# Guessing letter: t
# Sever response: {'game_id': '373856953a74', 'status': 'ongoing', 'tries_remains': 1, 'word': 's c _ i _ o _ o n i c '}
# Guessing letter: m
# Sever response: {'game_id': '373856953a74', 'status': 'failed', 'tries_remains': 0, 'word': 's c _ i _ o _ o n i c '}
# Failed game: 373856953a74. Because of: # of tries exceeded!
# run 9 practice games. practice success rate so far = 0.111
# Successfully start a new game! Game ID: 252a3c99a4f3. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '252a3c99a4f3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '252a3c99a4f3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ a _ '}
# Guessing letter: i
# Sever response: {'game_id': '252a3c99a4f3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i _ a _ '}
# Guessing letter: n
# Sever response: {'game_id': '252a3c99a4f3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ i _ a _ '}
# Guessing letter: o
# Sever response: {'game_id': '252a3c99a4f3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ i _ a _ '}
# Guessing letter: l
# Sever response: {'game_id': '252a3c99a4f3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ i _ a l '}
# Guessing letter: c
# Sever response: {'game_id': '252a3c99a4f3', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c _ _ i _ a l '}
# Guessing letter: m
# Sever response: {'game_id': '252a3c99a4f3', 'status': 'ongoing', 'tries_remains': 2, 'word': 'c _ _ i _ a l '}
# Guessing letter: r
# Sever response: {'game_id': '252a3c99a4f3', 'status': 'ongoing', 'tries_remains': 1, 'word': 'c _ _ i _ a l '}
# Guessing letter: y
# Sever response: {'game_id': '252a3c99a4f3', 'status': 'failed', 'tries_remains': 0, 'word': 'c _ _ i _ a l '}
# Failed game: 252a3c99a4f3. Because of: # of tries exceeded!
# run 10 practice games. practice success rate so far = 0.100
# Successfully start a new game! Game ID: 941440da0ab8. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '941440da0ab8', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e e _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '941440da0ab8', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ e e _ _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '941440da0ab8', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ e e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '941440da0ab8', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ e e _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '941440da0ab8', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ e e _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '941440da0ab8', 'status': 'ongoing', 'tries_remains': 2, 'word': 's _ e e _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '941440da0ab8', 'status': 'ongoing', 'tries_remains': 1, 'word': 's _ e e _ _ _ '}
# Guessing letter: y
# Sever response: {'game_id': '941440da0ab8', 'status': 'failed', 'tries_remains': 0, 'word': 's _ e e _ _ _ '}
# Failed game: 941440da0ab8. Because of: # of tries exceeded!
# run 11 practice games. practice success rate so far = 0.091
# Successfully start a new game! Game ID: ec909aa7afc9. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ _ _ _ _ e _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ _ _ _ _ e _ _ _ _ i _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 6, 'word': 'o _ e _ _ o _ _ e _ _ _ _ i o _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 6, 'word': 'o _ e _ _ o _ _ e _ _ a _ i o _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 6, 'word': 'o _ e _ _ o _ _ e n _ a _ i o n _ '}
# Guessing letter: l
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 5, 'word': 'o _ e _ _ o _ _ e n _ a _ i o n _ '}
# Guessing letter: s
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 5, 'word': 'o _ e _ _ o _ _ e n s a _ i o n s '}
# Guessing letter: c
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 5, 'word': 'o _ e _ c o _ _ e n s a _ i o n s '}
# Guessing letter: t
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 5, 'word': 'o _ e _ c o _ _ e n s a t i o n s '}
# Guessing letter: r
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 5, 'word': 'o _ e r c o _ _ e n s a t i o n s '}
# Guessing letter: u
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 4, 'word': 'o _ e r c o _ _ e n s a t i o n s '}
# Guessing letter: d
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 3, 'word': 'o _ e r c o _ _ e n s a t i o n s '}
# Guessing letter: j
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 2, 'word': 'o _ e r c o _ _ e n s a t i o n s '}
# Guessing letter: h
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'ongoing', 'tries_remains': 1, 'word': 'o _ e r c o _ _ e n s a t i o n s '}
# Guessing letter: z
# Sever response: {'game_id': 'ec909aa7afc9', 'status': 'failed', 'tries_remains': 0, 'word': 'o _ e r c o _ _ e n s a t i o n s '}
# Failed game: ec909aa7afc9. Because of: # of tries exceeded!
# run 12 practice games. practice success rate so far = 0.083
# Successfully start a new game! Game ID: ebbdb86340a9. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ e _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ e _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ e _ _ i _ n '}
# Guessing letter: o
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ e _ _ i o n '}
# Guessing letter: t
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ e _ _ i o n '}
# Guessing letter: p
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ e _ _ i o n '}
# Guessing letter: s
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ e s s i o n '}
# Guessing letter: a
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ _ e s s i o n '}
# Guessing letter: c
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ _ e s s i o n '}
# Guessing letter: r
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ r e s s i o n '}
# Guessing letter: l
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e _ r e s s i o n '}
# Guessing letter: d
# Sever response: {'game_id': 'ebbdb86340a9', 'status': 'failed', 'tries_remains': 0, 'word': 'e _ r e s s i o n '}
# Failed game: ebbdb86340a9. Because of: # of tries exceeded!
# run 13 practice games. practice success rate so far = 0.077
# Successfully start a new game! Game ID: 6279c8917e4f. # of tries remaining: 6. Word: _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '6279c8917e4f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '6279c8917e4f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '6279c8917e4f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '6279c8917e4f', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '6279c8917e4f', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '6279c8917e4f', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ _ '}
# Failed game: 6279c8917e4f. Because of: # of tries exceeded!
# run 14 practice games. practice success rate so far = 0.071
# Successfully start a new game! Game ID: fc494037ca0c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ i _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ a _ _ i _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ o _ _ _ a _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n o n _ _ a _ _ i n _ '}
# Guessing letter: g
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n o n _ _ a _ _ i n g '}
# Guessing letter: s
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n o n s _ a _ _ i n g '}
# Guessing letter: p
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'n o n s _ a _ _ i n g '}
# Guessing letter: t
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'n o n s t a _ t i n g '}
# Guessing letter: l
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n o n s t a _ t i n g '}
# Guessing letter: c
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n o n s t a _ t i n g '}
# Guessing letter: r
# Sever response: {'game_id': 'fc494037ca0c', 'status': 'success', 'tries_remains': 2, 'word': 'n o n s t a r t i n g '}
# Successfully finished game: fc494037ca0c
# run 15 practice games. practice success rate so far = 0.133
# Successfully start a new game! Game ID: 36002d2b2c72. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '36002d2b2c72', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '36002d2b2c72', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ e _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '36002d2b2c72', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i _ _ _ e _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '36002d2b2c72', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ i _ a _ e a _ '}
# Guessing letter: n
# Sever response: {'game_id': '36002d2b2c72', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ i n a _ e a n '}
# Guessing letter: o
# Sever response: {'game_id': '36002d2b2c72', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ i n a _ e a n '}
# Guessing letter: r
# Sever response: {'game_id': '36002d2b2c72', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ i n a _ e a n '}
# Guessing letter: l
# Sever response: {'game_id': '36002d2b2c72', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a l l i n a _ e a n '}
# Guessing letter: c
# Sever response: {'game_id': '36002d2b2c72', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a l l i n a c e a n '}
# Guessing letter: u
# Sever response: {'game_id': '36002d2b2c72', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a l l i n a c e a n '}
# Guessing letter: t
# Sever response: {'game_id': '36002d2b2c72', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a l l i n a c e a n '}
# Guessing letter: d
# Sever response: {'game_id': '36002d2b2c72', 'status': 'failed', 'tries_remains': 0, 'word': '_ a l l i n a c e a n '}
# Failed game: 36002d2b2c72. Because of: # of tries exceeded!
# run 16 practice games. practice success rate so far = 0.125
# Successfully start a new game! Game ID: 0c11ccfbc163. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '0c11ccfbc163', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '0c11ccfbc163', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '0c11ccfbc163', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '0c11ccfbc163', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ i n _ '}
# Guessing letter: g
# Sever response: {'game_id': '0c11ccfbc163', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ i n g '}
# Guessing letter: o
# Sever response: {'game_id': '0c11ccfbc163', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ i n g '}
# Guessing letter: l
# Sever response: {'game_id': '0c11ccfbc163', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ l i n g '}
# Guessing letter: b
# Sever response: {'game_id': '0c11ccfbc163', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ l i n g '}
# Guessing letter: s
# Sever response: {'game_id': '0c11ccfbc163', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ l i n g '}
# Guessing letter: r
# Sever response: {'game_id': '0c11ccfbc163', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ _ l i n g '}
# Guessing letter: d
# Sever response: {'game_id': '0c11ccfbc163', 'status': 'success', 'tries_remains': 1, 'word': 'd a d d l i n g '}
# Successfully finished game: 0c11ccfbc163
# run 17 practice games. practice success rate so far = 0.176
# Successfully start a new game! Game ID: e71541a4d887. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'e71541a4d887', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'e71541a4d887', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ i _ _ i _ i _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'e71541a4d887', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ i _ _ i _ i _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'e71541a4d887', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ i _ _ i _ i o _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'e71541a4d887', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ i _ _ i _ i o _ s '}
# Guessing letter: u
# Sever response: {'game_id': 'e71541a4d887', 'status': 'ongoing', 'tries_remains': 4, 'word': 'u _ i _ _ i _ i o u s '}
# Guessing letter: n
# Sever response: {'game_id': 'e71541a4d887', 'status': 'ongoing', 'tries_remains': 4, 'word': 'u n i n _ i _ i o u s '}
# Guessing letter: d
# Sever response: {'game_id': 'e71541a4d887', 'status': 'ongoing', 'tries_remains': 4, 'word': 'u n i n _ i d i o u s '}
# Guessing letter: j
# Sever response: {'game_id': 'e71541a4d887', 'status': 'ongoing', 'tries_remains': 3, 'word': 'u n i n _ i d i o u s '}
# Guessing letter: x
# Sever response: {'game_id': 'e71541a4d887', 'status': 'ongoing', 'tries_remains': 2, 'word': 'u n i n _ i d i o u s '}
# Guessing letter: z
# Sever response: {'game_id': 'e71541a4d887', 'status': 'ongoing', 'tries_remains': 1, 'word': 'u n i n _ i d i o u s '}
# Guessing letter: l
# Sever response: {'game_id': 'e71541a4d887', 'status': 'failed', 'tries_remains': 0, 'word': 'u n i n _ i d i o u s '}
# Failed game: e71541a4d887. Because of: # of tries exceeded!
# run 18 practice games. practice success rate so far = 0.167
# Successfully start a new game! Game ID: 1d8bc040411c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ i _ '}
# Guessing letter: a
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ _ a _ _ _ _ i _ '}
# Guessing letter: o
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ o _ a _ _ o _ i _ '}
# Guessing letter: c
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ o c a _ _ o _ i c '}
# Guessing letter: n
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ o c a _ _ o n i c '}
# Guessing letter: s
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ o c a _ _ o n i c '}
# Guessing letter: r
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ o c a r _ o n i c '}
# Guessing letter: l
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ o c a r _ o n i c '}
# Guessing letter: t
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ o c a r _ o n i c '}
# Guessing letter: u
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ u o c a r _ o n i c '}
# Guessing letter: y
# Sever response: {'game_id': '1d8bc040411c', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a _ u o c a r _ o n i c '}
# Guessing letter: d
# Sever response: {'game_id': '1d8bc040411c', 'status': 'failed', 'tries_remains': 0, 'word': 'a _ u o c a r _ o n i c '}
# Failed game: 1d8bc040411c. Because of: # of tries exceeded!
# run 19 practice games. practice success rate so far = 0.158
# Successfully start a new game! Game ID: c12c4cb77751. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'c12c4cb77751', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': 'c12c4cb77751', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ _ a _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'c12c4cb77751', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ a _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'c12c4cb77751', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ a _ e _ '}
# Guessing letter: i
# Sever response: {'game_id': 'c12c4cb77751', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ _ a _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': 'c12c4cb77751', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ _ a _ e d '}
# Guessing letter: l
# Sever response: {'game_id': 'c12c4cb77751', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a l _ _ a _ e d '}
# Guessing letter: c
# Sever response: {'game_id': 'c12c4cb77751', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a l _ _ a _ e d '}
# Guessing letter: t
# Sever response: {'game_id': 'c12c4cb77751', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a l _ _ a _ e d '}
# Guessing letter: n
# Sever response: {'game_id': 'c12c4cb77751', 'status': 'failed', 'tries_remains': 0, 'word': '_ a l _ _ a _ e d '}
# Failed game: c12c4cb77751. Because of: # of tries exceeded!
# run 20 practice games. practice success rate so far = 0.150
# Successfully start a new game! Game ID: 1a2114f70487. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1a2114f70487', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '1a2114f70487', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ a _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '1a2114f70487', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ a _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '1a2114f70487', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ a _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '1a2114f70487', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ _ _ a _ _ _ '}
# Guessing letter: u
# Sever response: {'game_id': '1a2114f70487', 'status': 'ongoing', 'tries_remains': 2, 'word': 's _ _ _ a _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '1a2114f70487', 'status': 'ongoing', 'tries_remains': 2, 'word': 's _ _ _ a r _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '1a2114f70487', 'status': 'ongoing', 'tries_remains': 1, 'word': 's _ _ _ a r _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '1a2114f70487', 'status': 'ongoing', 'tries_remains': 1, 'word': 's c _ _ a r _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '1a2114f70487', 'status': 'failed', 'tries_remains': 0, 'word': 's c _ _ a r _ _ '}
# Failed game: 1a2114f70487. Because of: # of tries exceeded!
# run 21 practice games. practice success rate so far = 0.143
# Successfully start a new game! Game ID: 467e7c9a4046. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '467e7c9a4046', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '467e7c9a4046', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ a _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '467e7c9a4046', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ a i _ i _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '467e7c9a4046', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ a i _ i _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '467e7c9a4046', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ a i _ i _ _ _ n '}
# Guessing letter: o
# Sever response: {'game_id': '467e7c9a4046', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ a i _ i _ _ o n '}
# Guessing letter: r
# Sever response: {'game_id': '467e7c9a4046', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a i r i _ _ o n '}
# Guessing letter: l
# Sever response: {'game_id': '467e7c9a4046', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a i r i l l o n '}
# Guessing letter: c
# Sever response: {'game_id': '467e7c9a4046', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r a i r i l l o n '}
# Guessing letter: u
# Sever response: {'game_id': '467e7c9a4046', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ r a i r i l l o n '}
# Guessing letter: t
# Sever response: {'game_id': '467e7c9a4046', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ r a i r i l l o n '}
# Guessing letter: d
# Sever response: {'game_id': '467e7c9a4046', 'status': 'failed', 'tries_remains': 0, 'word': '_ r a i r i l l o n '}
# Failed game: 467e7c9a4046. Because of: # of tries exceeded!
# run 22 practice games. practice success rate so far = 0.136
# Successfully start a new game! Game ID: 326b358b8edc. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i _ e _ _ i _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i _ e _ _ i n _ _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 6, 'word': 'd i _ e _ _ i n _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 5, 'word': 'd i _ e _ _ i n _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 4, 'word': 'd i _ e _ _ i n _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 3, 'word': 'd i _ e _ _ i n _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 3, 'word': 'd i _ e r _ i n _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 3, 'word': 'd i _ e r _ i n _ l _ '}
# Guessing letter: c
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 2, 'word': 'd i _ e r _ i n _ l _ '}
# Guessing letter: t
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 2, 'word': 'd i _ e r t i n _ l _ '}
# Guessing letter: y
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 2, 'word': 'd i _ e r t i n _ l y '}
# Guessing letter: u
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd i _ e r t i n _ l y '}
# Guessing letter: g
# Sever response: {'game_id': '326b358b8edc', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd i _ e r t i n g l y '}
# Guessing letter: b
# Sever response: {'game_id': '326b358b8edc', 'status': 'failed', 'tries_remains': 0, 'word': 'd i _ e r t i n g l y '}
# Failed game: 326b358b8edc. Because of: # of tries exceeded!
# run 23 practice games. practice success rate so far = 0.130
# Successfully start a new game! Game ID: d26374bcbdc7. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ _ e _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ _ e _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ _ e _ _ i _ n '}
# Guessing letter: o
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ o _ _ _ e _ _ i o n '}
# Guessing letter: a
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ o _ _ _ e _ _ i o n '}
# Guessing letter: u
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ u _ e _ _ o _ _ _ e _ _ i o n '}
# Guessing letter: l
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ u _ e _ _ o _ _ _ e _ _ i o n '}
# Guessing letter: s
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 4, 'word': 's u _ e _ _ o _ _ _ e s s i o n '}
# Guessing letter: r
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 4, 'word': 's u _ e r _ o _ _ r e s s i o n '}
# Guessing letter: c
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 4, 'word': 's u _ e r c o _ _ r e s s i o n '}
# Guessing letter: t
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 3, 'word': 's u _ e r c o _ _ r e s s i o n '}
# Guessing letter: d
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 2, 'word': 's u _ e r c o _ _ r e s s i o n '}
# Guessing letter: j
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'ongoing', 'tries_remains': 1, 'word': 's u _ e r c o _ _ r e s s i o n '}
# Guessing letter: b
# Sever response: {'game_id': 'd26374bcbdc7', 'status': 'failed', 'tries_remains': 0, 'word': 's u _ e r c o _ _ r e s s i o n '}
# Failed game: d26374bcbdc7. Because of: # of tries exceeded!
# run 24 practice games. practice success rate so far = 0.125
# Successfully start a new game! Game ID: b3a9c71afa10. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'b3a9c71afa10', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ e _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': 'b3a9c71afa10', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ e _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': 'b3a9c71afa10', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ e _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'b3a9c71afa10', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ s _ e _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'b3a9c71afa10', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ s _ e r e r '}
# Guessing letter: i
# Sever response: {'game_id': 'b3a9c71afa10', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e i s _ e r e r '}
# Guessing letter: o
# Sever response: {'game_id': 'b3a9c71afa10', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e i s _ e r e r '}
# Guessing letter: n
# Sever response: {'game_id': 'b3a9c71afa10', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e i s _ e r e r '}
# Guessing letter: l
# Sever response: {'game_id': 'b3a9c71afa10', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l e i s _ e r e r '}
# Guessing letter: c
# Sever response: {'game_id': 'b3a9c71afa10', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l e i s _ e r e r '}
# Guessing letter: t
# Sever response: {'game_id': 'b3a9c71afa10', 'status': 'success', 'tries_remains': 1, 'word': 'l e i s t e r e r '}
# Successfully finished game: b3a9c71afa10
# run 25 practice games. practice success rate so far = 0.160
# Successfully start a new game! Game ID: 5a6400c02f76. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '5a6400c02f76', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ e _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '5a6400c02f76', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i _ e _ _ _ e _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '5a6400c02f76', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i _ e _ _ _ e _ _ i _ n '}
# Guessing letter: a
# Sever response: {'game_id': '5a6400c02f76', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ e _ _ _ e _ _ i _ n '}
# Guessing letter: o
# Sever response: {'game_id': '5a6400c02f76', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ e _ _ _ e _ _ i o n '}
# Guessing letter: s
# Sever response: {'game_id': '5a6400c02f76', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i s e _ _ _ e s s i o n '}
# Guessing letter: u
# Sever response: {'game_id': '5a6400c02f76', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i s e _ _ _ e s s i o n '}
# Guessing letter: c
# Sever response: {'game_id': '5a6400c02f76', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i s e _ _ _ e s s i o n '}
# Guessing letter: r
# Sever response: {'game_id': '5a6400c02f76', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i s e _ _ r e s s i o n '}
# Guessing letter: l
# Sever response: {'game_id': '5a6400c02f76', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i s e _ _ r e s s i o n '}
# Guessing letter: t
# Sever response: {'game_id': '5a6400c02f76', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ i s e _ _ r e s s i o n '}
# Guessing letter: d
# Sever response: {'game_id': '5a6400c02f76', 'status': 'failed', 'tries_remains': 0, 'word': '_ i s e _ _ r e s s i o n '}
# Failed game: 5a6400c02f76. Because of: # of tries exceeded!
# run 26 practice games. practice success rate so far = 0.154
# Successfully start a new game! Game ID: 0d9d7d53f895. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '0d9d7d53f895', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '0d9d7d53f895', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '0d9d7d53f895', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ _ _ _ '}
# Guessing letter: o
# ...
# Sever response: {'game_id': 'c4a51b5a87a5', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'c4a51b5a87a5', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': 'c4a51b5a87a5', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'c4a51b5a87a5', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'c4a51b5a87a5', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': 'c4a51b5a87a5', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ '}
# Failed game: c4a51b5a87a5. Because of: # of tries exceeded!
# run 108 practice games. practice success rate so far = 0.111
# Successfully start a new game! Game ID: 26070e7e048e. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '26070e7e048e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': '26070e7e048e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': '26070e7e048e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '26070e7e048e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ e _ '}
# Guessing letter: i
# Sever response: {'game_id': '26070e7e048e', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ e _ '}
# Guessing letter: o
# Sever response: {'game_id': '26070e7e048e', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '26070e7e048e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o _ _ e _ '}
# Guessing letter: n
# Sever response: {'game_id': '26070e7e048e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o _ _ e n '}
# Guessing letter: l
# Sever response: {'game_id': '26070e7e048e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o l _ e n '}
# Guessing letter: b
# Sever response: {'game_id': '26070e7e048e', 'status': 'failed', 'tries_remains': 0, 'word': '_ o l _ e n '}
# Failed game: 26070e7e048e. Because of: # of tries exceeded!
# run 109 practice games. practice success rate so far = 0.110
# Successfully start a new game! Game ID: a0b868b8feef. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'a0b868b8feef', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': 'a0b868b8feef', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'a0b868b8feef', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'a0b868b8feef', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ o _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'a0b868b8feef', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ o _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'a0b868b8feef', 'status': 'ongoing', 'tries_remains': 2, 'word': 's _ o _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'a0b868b8feef', 'status': 'ongoing', 'tries_remains': 2, 'word': 's _ o n _ '}
# Guessing letter: y
# Sever response: {'game_id': 'a0b868b8feef', 'status': 'ongoing', 'tries_remains': 1, 'word': 's _ o n _ '}
# Guessing letter: h
# Sever response: {'game_id': 'a0b868b8feef', 'status': 'failed', 'tries_remains': 0, 'word': 's _ o n _ '}
# Failed game: a0b868b8feef. Because of: # of tries exceeded!
# run 110 practice games. practice success rate so far = 0.109
# Successfully start a new game! Game ID: 746252ced5ad. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '746252ced5ad', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '746252ced5ad', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '746252ced5ad', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '746252ced5ad', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o o _ _ o _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '746252ced5ad', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o o r _ o _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '746252ced5ad', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o o r _ o s _ '}
# Guessing letter: h
# Sever response: {'game_id': '746252ced5ad', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o o r _ o s _ '}
# Guessing letter: m
# Sever response: {'game_id': '746252ced5ad', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o o r _ o s _ '}
# Guessing letter: c
# Sever response: {'game_id': '746252ced5ad', 'status': 'failed', 'tries_remains': 0, 'word': '_ o o r _ o s _ '}
# Failed game: 746252ced5ad. Because of: # of tries exceeded!
# run 111 practice games. practice success rate so far = 0.108
# Successfully start a new game! Game ID: 561c89b51e65. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ s s _ e _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ a s s _ e _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ o _ _ a s s _ e _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 6, 'word': 'c o _ _ a s s _ e _ _ '}
# Guessing letter: m
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 6, 'word': 'c o m _ a s s m e _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 6, 'word': 'c o m _ a s s m e n _ '}
# Guessing letter: i
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 5, 'word': 'c o m _ a s s m e n _ '}
# Guessing letter: r
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 4, 'word': 'c o m _ a s s m e n _ '}
# Guessing letter: l
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c o m _ a s s m e n _ '}
# Guessing letter: u
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 2, 'word': 'c o m _ a s s m e n _ '}
# Guessing letter: t
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 2, 'word': 'c o m _ a s s m e n t '}
# Guessing letter: d
# Sever response: {'game_id': '561c89b51e65', 'status': 'ongoing', 'tries_remains': 1, 'word': 'c o m _ a s s m e n t '}
# Guessing letter: y
# Sever response: {'game_id': '561c89b51e65', 'status': 'failed', 'tries_remains': 0, 'word': 'c o m _ a s s m e n t '}
# Failed game: 561c89b51e65. Because of: # of tries exceeded!
# run 112 practice games. practice success rate so far = 0.107
# Successfully start a new game! Game ID: 9b844a9ee1a3. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '9b844a9ee1a3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': '9b844a9ee1a3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': '9b844a9ee1a3', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ e _ _ a _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '9b844a9ee1a3', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ e l l a _ l e '}
# Guessing letter: o
# Sever response: {'game_id': '9b844a9ee1a3', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ e l l a _ l e '}
# Guessing letter: n
# Sever response: {'game_id': '9b844a9ee1a3', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ e l l a _ l e '}
# Guessing letter: s
# Sever response: {'game_id': '9b844a9ee1a3', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ e l l a _ l e '}
# Guessing letter: r
# Sever response: {'game_id': '9b844a9ee1a3', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a _ _ e l l a _ l e '}
# Guessing letter: c
# Sever response: {'game_id': '9b844a9ee1a3', 'status': 'failed', 'tries_remains': 0, 'word': 'a _ _ e l l a _ l e '}
# Failed game: 9b844a9ee1a3. Because of: # of tries exceeded!
# run 113 practice games. practice success rate so far = 0.106
# Successfully start a new game! Game ID: 81f72a48a653. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '81f72a48a653', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '81f72a48a653', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ _ _ _ i _ _ _ i _ '}
# Guessing letter: a
# Sever response: {'game_id': '81f72a48a653', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ _ a _ i _ a _ i _ '}
# Guessing letter: o
# Sever response: {'game_id': '81f72a48a653', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ o a _ i _ a _ i _ '}
# Guessing letter: n
# Sever response: {'game_id': '81f72a48a653', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n i _ _ o a _ i _ a _ i n '}
# Guessing letter: s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 for _ in range(1000):
# ----> 2     api.start_game(practice=1,verbose=True)
#       3     [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
#       4     practice_success_rate = (total_practice_successes - 1319) / (total_practice_runs - 3394)
#
# Cell In[2], line 177, in HangmanAPI.start_game(self, practice, verbose)
#     174     print("Guessing letter: {0}".format(guess_letter))
#     176 try:
# --> 177     res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
#     178 except HangmanAPIError:
#     179     print('HangmanAPIError exception caught on request.')
#
# Cell In[2], line 230, in HangmanAPI.request(self, path, args, post_args, method)
#     228 for it in range(num_retry):
#     229     try:
# --> 230         response = self.session.request(
#     231             method or "GET",
#     232             self.hangman_url + path,
#     233             timeout=self.timeout,
#     234             params=args,
#     235             data=post_args,
#     236             verify=False
#     237         )
#     238         break
#     239     except requests.HTTPError as e:
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/envs/HangmanAI/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status()
print(total_practice_runs)
print(total_practice_successes)
# Out:
# 3394
# 1319

# %% [markdown]
# ## Playing recorded games:
# Please finalize your code prior to running the cell below. Once this code executes once successfully your submission will be finalized. Our system will not allow you to rerun any additional games.
#
# Please note that it is expected that after you successfully run this block of code that subsequent runs will result in the error message "Your account has been deactivated".
#
# Once you've run this section of the code your submission is complete. Please send us your source code via email.

# %%
for i in range(1000):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    #api.start_game(practice=0,verbose=False)
    
    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)

# %% [markdown]
# ## To check your game statistics
# 1. Simply use "my_status" method.
# 2. Returns your total number of games, and number of wins.

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
success_rate = total_recorded_successes/total_recorded_runs
print('overall success rate = %.3f' % success_rate)
